# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
import re
import math
from sklearn.naive_bayes import GaussianNB
import numpy as np

# %%
main = pd.read_csv('D:\Workspace\MS\DataScience\MiniProject2\data\jobs.csv', skiprows=0)
df = main[:3000]
test = main[3001:]

bt =df['Business Title']
cst=df['Civil Service Title']


main_bt =main['Business Title']
main_cst=main['Civil Service Title']

# %%
vec = CountVectorizer(tokenizer=tokenize)
main_data = vec.fit_transform(main_bt).toarray()
main_data1 = vec.fit_transform(main_cst).toarray()

data = vec.fit_transform(bt).toarray()
data1 = vec.fit_transform(cst).toarray()

main_combine = np.hstack([main_data,main_data1])
combine = np.hstack([data,data1])
test_combine = np.hstack([test_data,test_data1])

# %%
abv = np.random.random_integers(1,3000,3000)
abv1= np.random.random_integers(3000,3300,300)
ad  = main_combine[abv]
ad1 = main_combine[abv1]
f = open('C:\Users\Rahul\Desktop\sal.csv')
sal = []
lines= f.readlines()
count = 1
for line in lines:
    a = line.split(',')[3].strip()
    sal.append(int(a))
y = np.array(sal)

# %%
gnb = GaussianNB()
y_pred = gnb.fit(ad,b).predict(ad1)
print("Number of mislaxbeled points out of a total %d points : %d"% (data.shape[0],y != y_pred).sum()))

# %%
a=[]
unit= []
with open('C:\Users\Rahul\Desktop\SALLOCA.csv') as data:
    data = csv.reader(data,delimiter=',')
    for row in data:
        a.append((row[0],row[1])
# Out:
# [('200000', '520 1St Ave., N.Y.'), ('198518', '96-05 Horace Harding Expway'), ('198518', '96-05 Horace Harding Expway'), ('197275', '2 Lafayette St., N.Y.'), ('197275', '2 Lafayette St., N.Y.'), ('193259', '59-17 Junction Blvd Corona Ny'), ('193259', '59-17 Junction Blvd Corona Ny'), ('180000', '450 West 33 St, New York NY'), ('180000', '450 West 33 St, New York NY'), ('173490', '42-09 28th Street'), ('173490', '42-09 28th Street'), ('172000', '59-17 Junction Blvd Corona Ny'), ('172000', '59-17 Junction Blvd Corona Ny'), ('170000', '75-20 Astoria Blvd'), ('170000', '75-20 Astoria Blvd'), ('168453', '520 1St Ave., N.Y.'), ('168453', '520 1St Ave., N.Y.'), ('167198', '42-09 28th Street'), ('167198', '42-09 28th Street'), ('162500', '55 Water St Ny Ny'), ('162500', '55 Water St Ny Ny'), ('160000', '75-20 Astoria Blvd'), ('160000', '75-20 Astoria Blvd'), ('153619', '42-09 28th Street'), ('153619', '42-09 28th Street'), ('153493', '520 1St Ave., N.Y.'), ('153493', '520 1St Ave., N.Y.'), (
# ...

# %%
import collections

collections.Counter(unit)
# Out:
# Counter({'Bureau of Tech Deve and Syst': 62, 'Dept of Environment Protection': 49, 'IT Svcs Delivery': 42, 'Enterprise APP Services': 39, 'Default': 36, 'Citywide': 30, 'Pub Bldgs/Various': 27, 'Information Technology': 24, 'OCME-Operations': 23, 'Executive Management': 23, 'MIRH Newborn Home Visiting': 22, 'Headstart (ECE)': 22, 'Pub Bldgs/Admin Supp': 22, 'SH Reproductive Health': 20, 'Pest Control Services': 19, 'SH Nursing Services & Prof Dev': 18, 'Office Of Contracts-NM': 18, 'Civilian Complaint Review Bd': 18, 'Counsels Office': 18, 'Green Infrastructure': 18, 'JOCS- IFA': 18, 'Information Systems-Admin': 16, 'Executive Deputy Com': 16, 'HIV/AIDS Epidem & Field Srvcs': 16, 'Admin/Budget & Finance-Exec': 16, 'IT & Telecom': 16, 'Early Intervention': 16, 'Dpty Comm Fnancl Svcs-Finance': 16, 'Commissioner': 16, 'Fed-St-Other Cat Claims & Revs': 16, 'Deputy Comm For Capital Pro': 15, 'Child Care': 14, 'Technology & Strategic Develop': 14, 'Mis Admin,Network Sysms Dvlpmt': 14, 'IT 
# ...

# %%
# Out:
# Number of mislaxbeled points out of a total 3000 points : 94

# %%
ba
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-c46e1ffcd01e> in <module>()
# ----> 1 ba
#
# NameError: name 'ba' is not defined
